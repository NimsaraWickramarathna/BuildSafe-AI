# %%
print("BuildSafe AI - Data Understanding")
# Out:
# BuildSafe AI - Data Understanding

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 3.0.5

# %%
from pathlib import Path

data_folder = Path("../data/raw")

files = list(data_folder.glob("*.csv"))

for file in files:
    print(file.name)
# Out:
# DOB_ECB_Violations_20260913 (1).csv

# %%
import pandas as pd

file_path = "../data/raw/DOB_ECB_Violations_20260913 (1).csv"

df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!
# C:\Users\wenur\AppData\Local\Temp\ipykernel_19416\3939217174.py:5: DtypeWarning: Columns (0: SECTION_LAW_DESCRIPTION3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
# Out:
# Rows: 102467
# Columns: 46

# %%
df.head()
# Out:
#    ISN_DOB_BIS_EXTRACT ECB_VIOLATION_NUMBER ECB_VIOLATION_STATUS  \
# 0              1749575            39190613X              RESOLVE
# 1              1729620            39156049P               ACTIVE
# 2              1801198            39193627K               ACTIVE
# 3              1793922            39169086R               ACTIVE
# 4              1741922            35730749Y               ACTIVE
#
#   DOB_VIOLATION_NUMBER        BIN  BORO   BLOCK   LOT  HEARING_DATE  \
# 0                  NaN  2026562.0     2  3813.0  19.0      20260821
# 1                  NaN  1003388.0     1   279.0  69.0      20270415
# 2                  NaN  5020516.0     5   795.0  41.0      20260902
# 3                  NaN  4139680.0     4  6381.0  54.0      20260908
# 4     07222026SR07NS01  2016355.0     2  3277.0   2.0      20261030
#
#    HEARING_TIME  ...  SECTION_LAW_DESCRIPTION7  INFRACTION_CODE8  \
# 0           930  ...                       NaN               NaN
# 1           830  ...                       NaN               NaN
# 2           930  ...                       NaN               NaN
# 3           830  ...                       NaN               NaN
# 4           830  ...                       NaN               NaN
#
#   SECTION_LAW_DESCRIPTION8 INFRACTION_CODE9 SECTION_LAW_DESCRIPTION9  \
# 0                      NaN              NaN                      NaN
# 1                      NaN              NaN                      NaN
# 2                      NaN              NaN                      NaN
# 3                      NaN              NaN                      NaN
# 4                      NaN              NaN                      NaN
#
#   INFRACTION_CODE10 SECTION_LAW_DESCRIPTION10 AGGRAVATED_LEVEL HEARING_STATUS  \
# 0               NaN                       NaN               NO   IN VIOLATION
# 1               NaN                       NaN               NO        PENDING
# 2               NaN                       NaN               NO        DEFAULT
# 3               NaN                       NaN               NO        PENDING
# 4               NaN                       NaN               NO        PENDING
#
#      CERTIFICATION_STATUS
# 0    CERTIFICATE ACCEPTED
# 1                     NaN
# 2  NO COMPLIANCE RECORDED
# 3                     NaN
# 4                     NaN
#
# [5 rows x 46 columns]

# %%
print(df.columns.tolist())
# Out:
# ['ISN_DOB_BIS_EXTRACT', 'ECB_VIOLATION_NUMBER', 'ECB_VIOLATION_STATUS', 'DOB_VIOLATION_NUMBER', 'BIN', 'BORO', 'BLOCK', 'LOT', 'HEARING_DATE', 'HEARING_TIME', 'SERVED_DATE', 'ISSUE_DATE', 'SEVERITY', 'VIOLATION_TYPE', 'RESPONDENT_NAME', 'RESPONDENT_HOUSE_NUMBER', 'RESPONDENT_STREET', 'RESPONDENT_CITY', 'RESPONDENT_ZIP', 'VIOLATION_DESCRIPTION', 'PENALITY_IMPOSED', 'AMOUNT_PAID', 'BALANCE_DUE', 'INFRACTION_CODE1', 'SECTION_LAW_DESCRIPTION1', 'INFRACTION_CODE2', 'SECTION_LAW_DESCRIPTION2', 'INFRACTION_CODE3', 'SECTION_LAW_DESCRIPTION3', 'INFRACTION_CODE4', 'SECTION_LAW_DESCRIPTION4', 'INFRACTION_CODE5', 'SECTION_LAW_DESCRIPTION5', 'INFRACTION_CODE6', 'SECTION_LAW_DESCRIPTION6', 'INFRACTION_CODE7', 'SECTION_LAW_DESCRIPTION7', 'INFRACTION_CODE8', 'SECTION_LAW_DESCRIPTION8', 'INFRACTION_CODE9', 'SECTION_LAW_DESCRIPTION9', 'INFRACTION_CODE10', 'SECTION_LAW_DESCRIPTION10', 'AGGRAVATED_LEVEL', 'HEARING_STATUS', 'CERTIFICATION_STATUS']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 102467 entries, 0 to 102466
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ISN_DOB_BIS_EXTRACT        102467 non-null  int64
#  1   ECB_VIOLATION_NUMBER       102467 non-null  str
#  2   ECB_VIOLATION_STATUS       102467 non-null  str
#  3   DOB_VIOLATION_NUMBER       21654 non-null   str
#  4   BIN                        102372 non-null  float64
#  5   BORO                       102467 non-null  int64
#  6   BLOCK                      101980 non-null  float64
#  7   LOT                        101980 non-null  float64
#  8   HEARING_DATE               102467 non-null  int64
#  9   HEARING_TIME               102467 non-null  int64
#  10  SERVED_DATE                102467 non-null  int64
#  11  ISSUE_DATE                 102467 non-null  int64
#  12  SEVERITY                   102467 non-null  str
#  13  VIOLATION_TYPE             102467 non-null  str
#  14  RESPONDENT_NAME            102392 non-null  str
#  15  RESPONDENT_HOUSE_NUMBER    79713 non-null   str
#  16  RESPONDENT_STREET          94683 non-null   str
#  17  RESPONDENT_CITY            94188 non-null   str
#  18  RESPONDENT_ZIP             93535 non-null   str
#  19  VIOLATION_DESCRIPTION      102459 non-null  str
#  20  PENALITY_IMPOSED           102467 non-null  str
#  21  AMOUNT_PAID                102467 non-null  str
#  22  BALANCE_DUE                102467 non-null  str
#  23  INFRACTION_CODE1           102467 non-null  str
#  24  SECTION_LAW_DESCRIPTION1   94473 non-null   str
#  25  INFRACTION_CODE2           2603 non-null    str
#  26  SECTION_LAW_DESCRIPTION2   2125 non-null    str
#  27  INFRACTION_CODE3           20 non-null      float64
#  28  SECTION_LAW_DESCRIPTION3   20 non-null      str
#  29  INFRACTION_CODE4           0 non-null       float64
#  30  SECTION_LAW_DESCRIPTION4   0 non-null       float64
#  31  INFRACTION_CODE5           0 non-null       float64
#  32  SECTION_LAW_DESCRIPTION5   0 non-null       float64
#  33  INFRACTION_CODE6           0 non-null       float64
#  34  SECTION_LAW_DESCRIPTION6   0 non-null       float64
#  35  INFRACTION_CODE7           0 non-null       float64
#  36  SECTION_LAW_DESCRIPTION7   0 non-null       float64
#  37  INFRACTION_CODE8           0 non-null       float64
#  38  SECTION_LAW_DESCRIPTION8   0 non-null       float64
#  39  INFRACTION_CODE9           0 non-null       float64
#  40  SECTION_LAW_DESCRIPTION9   0 non-null       float64
#  41  INFRACTION_CODE10          0 non-null       float64
#  42  SECTION_LAW_DESCRIPTION10  0 non-null       float64
#  43  AGGRAVATED_LEVEL           102467 non-null  str
#  44  HEARING_STATUS             93663 non-null   str
#  45  CERTIFICATION_STATUS       70646 non-null   str
# dtypes: float64(18), int64(6), str(22)
# memory usage: 36.0 MB

# %%
missing = df.isnull().sum()

missing = missing[missing > 0].sort_values(ascending=False)

print(missing)
# Out:
# INFRACTION_CODE7             102467
# SECTION_LAW_DESCRIPTION10    102467
# INFRACTION_CODE10            102467
# SECTION_LAW_DESCRIPTION9     102467
# INFRACTION_CODE9             102467
# SECTION_LAW_DESCRIPTION8     102467
# INFRACTION_CODE8             102467
# SECTION_LAW_DESCRIPTION7     102467
# INFRACTION_CODE5             102467
# SECTION_LAW_DESCRIPTION6     102467
# INFRACTION_CODE6             102467
# SECTION_LAW_DESCRIPTION5     102467
# INFRACTION_CODE4             102467
# SECTION_LAW_DESCRIPTION4     102467
# INFRACTION_CODE3             102447
# SECTION_LAW_DESCRIPTION3     102447
# SECTION_LAW_DESCRIPTION2     100342
# INFRACTION_CODE2              99864
# DOB_VIOLATION_NUMBER          80813
# CERTIFICATION_STATUS          31821
# RESPONDENT_HOUSE_NUMBER       22754
# RESPONDENT_ZIP                 8932
# HEARING_STATUS                 8804
# RESPONDENT_CITY                8279
# SECTION_LAW_DESCRIPTION1       7994
# RESPONDENT_STREET              7784
# LOT                             487
# BLOCK                           487
# BIN                              95
# RESPONDENT_NAME                  75
# VIOLATION_DESCRIPTION             8
# dtype: int64

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
print(df["SEVERITY"].value_counts(dropna=False))
# Out:
# SEVERITY
# CLASS - 2    57607
# CLASS - 1    40673
# CLASS - 3     4187
# Name: count, dtype: int64

# %%
print(df["SEVERITY"].value_counts(normalize=True, dropna=False) * 100)
# Out:
# SEVERITY
# CLASS - 2    56.220051
# CLASS - 1    39.693755
# CLASS - 3     4.086194
# Name: proportion, dtype: float64

# %%
print(df["SEVERITY"].unique())
# Out:
# <StringArray>
# ['CLASS - 2', 'CLASS - 1', 'CLASS - 3']
# Length: 3, dtype: str

# %%
date_columns = [
    "HEARING_DATE",
    "SERVED_DATE",
    "ISSUE_DATE"
]

for col in date_columns:
    print(f"\n{col}")
    print("Min:", df[col].min())
    print("Max:", df[col].max())
# Out:
# HEARING_DATE
# Min: 20250206
# Max: 20271222
#
# SERVED_DATE
# Min: 0
# Max: 20260910
#
# ISSUE_DATE
# Min: 20250101
# Max: 20260910

# %%
summary = pd.DataFrame({
    "Column": df.columns,
    "Data_Type": df.dtypes.astype(str).values,
    "Missing_Count": df.isnull().sum().values,
    "Missing_Percentage": (df.isnull().mean() * 100).values,
    "Unique_Values": df.nunique(dropna=True).values
})

summary
# Out:
#                        Column Data_Type  Missing_Count  Missing_Percentage  \
# 0         ISN_DOB_BIS_EXTRACT     int64              0            0.000000
# 1        ECB_VIOLATION_NUMBER       str              0            0.000000
# 2        ECB_VIOLATION_STATUS       str              0            0.000000
# 3        DOB_VIOLATION_NUMBER       str          80813           78.867343
# 4                         BIN   float64             95            0.092713
# 5                        BORO     int64              0            0.000000
# 6                       BLOCK   float64            487            0.475275
# 7                         LOT   float64            487            0.475275
# 8                HEARING_DATE     int64              0            0.000000
# 9                HEARING_TIME     int64              0            0.000000
# 10                SERVED_DATE     int64              0            0.000000
# 11                 ISSUE_DATE     int64              0            0.000000
# 12                   SEVERITY       str              0            0.000000
# 13             VIOLATION_TYPE       str              0            0.000000
# 14            RESPONDENT_NAME       str             75            0.073194
# 15    RESPONDENT_HOUSE_NUMBER       str          22754           22.206174
# 16          RESPONDENT_STREET       str           7784            7.596592
# 17            RESPONDENT_CITY       str           8279            8.079674
# 18             RESPONDENT_ZIP       str           8932            8.716953
# 19      VIOLATION_DESCRIPTION       str              8            0.007807
# 20           PENALITY_IMPOSED       str              0            0.000000
# 21                AMOUNT_PAID       str              0            0.000000
# 22                BALANCE_DUE       str              0            0.000000
# 23           INFRACTION_CODE1       str              0            0.000000
# 24   SECTION_LAW_DESCRIPTION1       str           7994            7.801536
# 25           INFRACTION_CODE2       str          99864           97.459670
# 26   SECTION_LAW_DESCRIPTION2       str         100342           97.926162
# 27           INFRACTION_CODE3   float64         102447           99.980482
# 28   SECTION_LAW_DESCRIPTION3       str         102447           99.980482
# 29           INFRACTION_CODE4   float64         102467          100.000000
# 30   SECTION_LAW_DESCRIPTION4   float64         102467          100.000000
# 31           INFRACTION_CODE5   float64         102467          100.000000
# 32   SECTION_LAW_DESCRIPTION5   float64         102467          100.000000
# 33           INFRACTION_CODE6   float64         102467          100.000000
# 34   SECTION_LAW_DESCRIPTION6   float64         102467          100.000000
# 35           INFRACTION_CODE7   float64         102467          100.000000
# 36   SECTION_LAW_DESCRIPTION7   float64         102467          100.000000
# 37           INFRACTION_CODE8   float64         102467          100.000000
# 38   SECTION_LAW_DESCRIPTION8   float64         102467          100.000000
# 39           INFRACTION_CODE9   float64         102467          100.000000
# 40   SECTION_LAW_DESCRIPTION9   float64         102467          100.000000
# 41          INFRACTION_CODE10   float64         102467          100.000000
# 42  SECTION_LAW_DESCRIPTION10   float64         102467          100.000000
# 43           AGGRAVATED_LEVEL       str              0            0.000000
# 44             HEARING_STATUS       str           8804            8.592035
# 45       CERTIFICATION_STATUS       str          31821           31.054876
#
#     Unique_Values
# 0          102467
# 1          102467
# 2               2
# 3           19986
# 4           38743
# 5               5
# 6            9887
# 7             643
# 8             568
# 9              39
# 10            619
# 11            618
# 12              3
# 13             12
# 14          36932
# 15           8702
# 16          10036
# 17           1312
# 18           1411
# 19          97978
# 20             98
# 21           1286
# 22            380
# 23            326
# 24            225
# 25            128
# 26             89
# 27              2
# 28              2
# 29              0
# 30              0
# 31              0
# 32              0
# 33              0
# 34              0
# 35              0
# 36              0
# 37              0
# 38              0
# 39              0
# 40              0
# 41              0
# 42              0
# 43              3
# 44              8
# 45              5

# %%
summary.sort_values(
    by="Missing_Percentage",
    ascending=False
)
# Out:
#                        Column Data_Type  Missing_Count  Missing_Percentage  \
# 30   SECTION_LAW_DESCRIPTION4   float64         102467          100.000000
# 33           INFRACTION_CODE6   float64         102467          100.000000
# 34   SECTION_LAW_DESCRIPTION6   float64         102467          100.000000
# 31           INFRACTION_CODE5   float64         102467          100.000000
# 32   SECTION_LAW_DESCRIPTION5   float64         102467          100.000000
# 37           INFRACTION_CODE8   float64         102467          100.000000
# 38   SECTION_LAW_DESCRIPTION8   float64         102467          100.000000
# 39           INFRACTION_CODE9   float64         102467          100.000000
# 40   SECTION_LAW_DESCRIPTION9   float64         102467          100.000000
# 41          INFRACTION_CODE10   float64         102467          100.000000
# 42  SECTION_LAW_DESCRIPTION10   float64         102467          100.000000
# 35           INFRACTION_CODE7   float64         102467          100.000000
# 36   SECTION_LAW_DESCRIPTION7   float64         102467          100.000000
# 29           INFRACTION_CODE4   float64         102467          100.000000
# 28   SECTION_LAW_DESCRIPTION3       str         102447           99.980482
# 27           INFRACTION_CODE3   float64         102447           99.980482
# 26   SECTION_LAW_DESCRIPTION2       str         100342           97.926162
# 25           INFRACTION_CODE2       str          99864           97.459670
# 3        DOB_VIOLATION_NUMBER       str          80813           78.867343
# 45       CERTIFICATION_STATUS       str          31821           31.054876
# 15    RESPONDENT_HOUSE_NUMBER       str          22754           22.206174
# 18             RESPONDENT_ZIP       str           8932            8.716953
# 44             HEARING_STATUS       str           8804            8.592035
# 17            RESPONDENT_CITY       str           8279            8.079674
# 24   SECTION_LAW_DESCRIPTION1       str           7994            7.801536
# 16          RESPONDENT_STREET       str           7784            7.596592
# 6                       BLOCK   float64            487            0.475275
# 7                         LOT   float64            487            0.475275
# 4                         BIN   float64             95            0.092713
# 14            RESPONDENT_NAME       str             75            0.073194
# 19      VIOLATION_DESCRIPTION       str              8            0.007807
# 12                   SEVERITY       str              0            0.000000
# 13             VIOLATION_TYPE       str              0            0.000000
# 10                SERVED_DATE     int64              0            0.000000
# 9                HEARING_TIME     int64              0            0.000000
# 8                HEARING_DATE     int64              0            0.000000
# 2        ECB_VIOLATION_STATUS       str              0            0.000000
# 5                        BORO     int64              0            0.000000
# 0         ISN_DOB_BIS_EXTRACT     int64              0            0.000000
# 1        ECB_VIOLATION_NUMBER       str              0            0.000000
# 11                 ISSUE_DATE     int64              0            0.000000
# 21                AMOUNT_PAID       str              0            0.000000
# 23           INFRACTION_CODE1       str              0            0.000000
# 22                BALANCE_DUE       str              0            0.000000
# 20           PENALITY_IMPOSED       str              0            0.000000
# 43           AGGRAVATED_LEVEL       str              0            0.000000
#
#     Unique_Values
# 30              0
# 33              0
# 34              0
# 31              0
# 32              0
# 37              0
# 38              0
# 39              0
# 40              0
# 41              0
# 42              0
# 35              0
# 36              0
# 29              0
# 28              2
# 27              2
# 26             89
# 25            128
# 3           19986
# 45              5
# 15           8702
# 18           1411
# 44              8
# 17           1312
# 24            225
# 16          10036
# 6            9887
# 7             643
# 4           38743
# 14          36932
# 19          97978
# 12              3
# 13             12
# 10            619
# 9              39
# 8             568
# 2               2
# 5               5
# 0          102467
# 1          102467
# 11            618
# 21           1286
# 23            326
# 22            380
# 20             98
# 43              3

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\wenur\AppData\Local\Programs\Python\Python313\python.exe

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (3.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\wenur\appdata\roaming\python\python313\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=9 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\wenur\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.3.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\wenur\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\wenur\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
print("Matplotlib works!")
# Out:
# Matplotlib works!

# %%
df["SEVERITY"].value_counts().plot(
    kind="bar",
    title="Severity Class Distribution"
)

plt.xlabel("Severity")
plt.ylabel("Number of Records")
plt.show()

# %%
df["SEVERITY"].value_counts().plot(
    kind="bar",
    title="Severity Class Distribution"
);

# %%
df["SEVERITY"].value_counts(normalize=True).mul(100)
# Out:
# SEVERITY
# CLASS - 2    56.220051
# CLASS - 1    39.693755
# CLASS - 3     4.086194
# Name: proportion, dtype: float64

# %%
categorical_columns = df.select_dtypes(include=["object", "str"]).columns

print("Number of categorical columns:", len(categorical_columns))

for col in categorical_columns:
    print(f"{col}: {df[col].nunique(dropna=True)} unique values")
# Out:
# Number of categorical columns: 22
# ECB_VIOLATION_NUMBER: 102467 unique values
# ECB_VIOLATION_STATUS: 2 unique values
# DOB_VIOLATION_NUMBER: 19986 unique values
# SEVERITY: 3 unique values
# VIOLATION_TYPE: 12 unique values
# RESPONDENT_NAME: 36932 unique values
# RESPONDENT_HOUSE_NUMBER: 8702 unique values
# RESPONDENT_STREET: 10036 unique values
# RESPONDENT_CITY: 1312 unique values
# RESPONDENT_ZIP: 1411 unique values
# VIOLATION_DESCRIPTION: 97978 unique values
# PENALITY_IMPOSED: 98 unique values
# AMOUNT_PAID: 1286 unique values
# BALANCE_DUE: 380 unique values
# INFRACTION_CODE1: 326 unique values
# SECTION_LAW_DESCRIPTION1: 225 unique values
# INFRACTION_CODE2: 128 unique values
# SECTION_LAW_DESCRIPTION2: 89 unique values
# SECTION_LAW_DESCRIPTION3: 2 unique values
# AGGRAVATED_LEVEL: 3 unique values
# HEARING_STATUS: 8 unique values
# CERTIFICATION_STATUS: 5 unique values

# %%
important_columns = [
    "ECB_VIOLATION_STATUS",
    "VIOLATION_TYPE",
    "SEVERITY",
    "AGGRAVATED_LEVEL",
    "HEARING_STATUS",
    "CERTIFICATION_STATUS"
]

for col in important_columns:
    print(f"\n{'='*50}")
    print(col)
    print(df[col].value_counts(dropna=False))
# Out:
# ==================================================
# ECB_VIOLATION_STATUS
# ECB_VIOLATION_STATUS
# ACTIVE     59031
# RESOLVE    43436
# Name: count, dtype: int64
#
# ==================================================
# VIOLATION_TYPE
# VIOLATION_TYPE
# Construction           74655
# Unknown                13585
# Elevators               6999
# Boilers                 2275
# Zoning                  1385
# Local Law               1241
# Quality of Life          917
# Site Safety              580
# Cranes and Derricks      355
# Plumbing                 280
# Signs                    178
# Public Assembly           17
# Name: count, dtype: int64
#
# ==================================================
# SEVERITY
# SEVERITY
# CLASS - 2    57607
# CLASS - 1    40673
# CLASS - 3     4187
# Name: count, dtype: int64
#
# ==================================================
# AGGRAVATED_LEVEL
# AGGRAVATED_LEVEL
# NO                            94199
# AGGRAVATED OFFENSE LEVEL 1     7323
# AGGRAVATED OFFENSE LEVEL 2      945
# Name: count, dtype: int64
#
# ==================================================
# HEARING_STATUS
# HEARING_STATUS
# DEFAULT               23087
# IN VIOLATION          21061
# PENDING               20952
# NaN                    8804
# POP/IN-VIO             8266
# CURED/IN-VIO           6675
# DISMISSED              6625
# ADMIT/IN-VIO           5871
# STIPULATION/IN-VIO     1126
# Name: count, dtype: int64
#
# ==================================================
# CERTIFICATION_STATUS
# CERTIFICATION_STATUS
# NaN                       31821
# CERTIFICATE ACCEPTED      30701
# NO COMPLIANCE RECORDED    27211
# CURE ACCEPTED              6675
# N/A - DISMISSED            4934
# COMPLIANCE-INSP/DOC        1125
# Name: count, dtype: int64

# %%
date_columns = [
    "HEARING_DATE",
    "SERVED_DATE",
    "ISSUE_DATE"
]

for col in date_columns:
    print(f"\n{col}")
    print(df[col].value_counts().head(10))
# Out:
# HEARING_DATE
# HEARING_DATE
# 20261007    815
# 20261016    756
# 20261110    755
# 20261014    658
# 20261002    648
# 20260807    643
# 20261030    617
# 20260715    616
# 20261104    615
# 20261028    593
# Name: count, dtype: int64
#
# SERVED_DATE
# SERVED_DATE
# 20260604    396
# 20250424    375
# 20260507    371
# 20260521    371
# 20250807    370
# 20250501    370
# 20250717    368
# 20260601    367
# 20260512    365
# 20250731    362
# Name: count, dtype: int64
#
# ISSUE_DATE
# ISSUE_DATE
# 20250408    985
# 20250225    956
# 20250701    861
# 20260420    726
# 20250129    565
# 20250211    453
# 20250528    424
# 20250108    404
# 20260302    350
# 20260730    343
# Name: count, dtype: int64

# %%
numeric_columns = df.select_dtypes(include=["int64", "float64"]).columns

df[numeric_columns].describe().T
# Out:
#                               count          mean           std         min  \
# ISN_DOB_BIS_EXTRACT        102467.0  1.565285e+06  3.710298e+05        81.0
# BIN                        102372.0  2.901839e+06  1.206617e+06   1000000.0
# BORO                       102467.0  2.762128e+00  1.136447e+00         1.0
# BLOCK                      101980.0  3.900134e+03  3.253183e+03         1.0
# LOT                        101980.0  3.363810e+02  1.442267e+03         0.0
# HEARING_DATE               102467.0  2.025916e+07  5.949054e+03  20250206.0
# HEARING_TIME               102467.0  8.984060e+02  9.128378e+01       800.0
# SERVED_DATE                102467.0  2.025365e+07  1.674797e+05         0.0
# ISSUE_DATE                 102467.0  2.025494e+07  4.881917e+03  20250101.0
# INFRACTION_CODE3               20.0  9.500001e+07  2.236064e+07       176.0
# INFRACTION_CODE4                0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION4        0.0           NaN           NaN         NaN
# INFRACTION_CODE5                0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION5        0.0           NaN           NaN         NaN
# INFRACTION_CODE6                0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION6        0.0           NaN           NaN         NaN
# INFRACTION_CODE7                0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION7        0.0           NaN           NaN         NaN
# INFRACTION_CODE8                0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION8        0.0           NaN           NaN         NaN
# INFRACTION_CODE9                0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION9        0.0           NaN           NaN         NaN
# INFRACTION_CODE10               0.0           NaN           NaN         NaN
# SECTION_LAW_DESCRIPTION10       0.0           NaN           NaN         NaN
#
#                                     25%          50%           75%  \
# ISN_DOB_BIS_EXTRACT        1.435650e+06    1736202.0  1.806802e+06
# BIN                        2.012957e+06    3089176.0  4.032027e+06
# BORO                       2.000000e+00          3.0  4.000000e+00
# BLOCK                      1.475000e+03       2999.0  5.399000e+03
# LOT                        1.300000e+01         33.0  5.900000e+01
# HEARING_DATE               2.025120e+07   20260617.0  2.026102e+07
# HEARING_TIME               8.300000e+02        830.0  9.300000e+02
# SERVED_DATE                2.025062e+07   20251121.0  2.026042e+07
# ISSUE_DATE                 2.025060e+07   20251117.0  2.026042e+07
# INFRACTION_CODE3           1.000000e+08  100000000.0  1.000000e+08
# INFRACTION_CODE4                    NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION4            NaN          NaN           NaN
# INFRACTION_CODE5                    NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION5            NaN          NaN           NaN
# INFRACTION_CODE6                    NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION6            NaN          NaN           NaN
# INFRACTION_CODE7                    NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION7            NaN          NaN           NaN
# INFRACTION_CODE8                    NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION8            NaN          NaN           NaN
# INFRACTION_CODE9                    NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION9            NaN          NaN           NaN
# INFRACTION_CODE10                   NaN          NaN           NaN
# SECTION_LAW_DESCRIPTION10           NaN          NaN           NaN
#
#                                    max
# ISN_DOB_BIS_EXTRACT          1847514.0
# BIN                          5871468.0
# BORO                               5.0
# BLOCK                          20179.0
# LOT                             9999.0
# HEARING_DATE                20271222.0
# HEARING_TIME                    1910.0
# SERVED_DATE                 20260910.0
# ISSUE_DATE                  20260910.0
# INFRACTION_CODE3           100000000.0
# INFRACTION_CODE4                   NaN
# SECTION_LAW_DESCRIPTION4           NaN
# INFRACTION_CODE5                   NaN
# SECTION_LAW_DESCRIPTION5           NaN
# INFRACTION_CODE6                   NaN
# SECTION_LAW_DESCRIPTION6           NaN
# INFRACTION_CODE7                   NaN
# SECTION_LAW_DESCRIPTION7           NaN
# INFRACTION_CODE8                   NaN
# SECTION_LAW_DESCRIPTION8           NaN
# INFRACTION_CODE9                   NaN
# SECTION_LAW_DESCRIPTION9           NaN
# INFRACTION_CODE10                  NaN
# SECTION_LAW_DESCRIPTION10          NaN
